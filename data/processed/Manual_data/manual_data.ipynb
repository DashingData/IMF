# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/home/abhishek/Desktop/IMF/data/raw/manual_labels/manually_default.csv")

# %%
df.head(20)
# Out:
#            Country  Manual Sovereign Default Label Year of Default  \
# 0            India                               0             NaN
# 1           Russia                               1      1998, 2022
# 2            China                               0             NaN
# 3     South Africa                               0             NaN
# 4    United States                               0             NaN
# 5   United Kingdom                               0             NaN
# 6            Italy                               0             NaN
# 7           France                               0             NaN
# 8          Germany                               0             NaN
# 9        Sri Lanka                               1            2022
# 10           Japan                               0             NaN
# 11          Brazil                               0             NaN
# 12      Bangladesh                               0             NaN
#
# ...
