# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("/home/abhishek/Desktop/IMF/data/raw/weo/weo_raw_dataset.csv")

# %%
df.head()
# Out:
#               DATASET        SERIES_CODE OBS_MEASURE             COUNTRY  \
# 0  IMF.RES:WEO(6.0.0)     MMR.GGX_NGDP.A   OBS_VALUE             Myanmar
# 1  IMF.RES:WEO(6.0.0)  LKA.GGXWDG_NGDP.A   OBS_VALUE           Sri Lanka
# 2  IMF.RES:WEO(6.0.0)      RUS.PCPIPCH.A   OBS_VALUE  Russian Federation
# 3  IMF.RES:WEO(6.0.0)  RUS.GGXWDG_NGDP.A   OBS_VALUE  Russian Federation
# 4  IMF.RES:WEO(6.0.0)     LKA.GGX_NGDP.A   OBS_VALUE           Sri Lanka
#
#                                            INDICATOR FREQUENCY  SCALE    2005  \
# 0    Expenditure, General government, Percent of GDP    Annual  Units  14.644
# 1     Gross debt, General government, Percent of GDP    Annual  Units  76.589
# 2  All Items, Consumer price index (CPI), Period ...    Annual  Units  12.685
# 3     Gross debt, General government, Percent of GDP    Annual  Units  14.851
# 4    Expenditure, General government, Percent of GDP    Annual  Units  20.145
#
# ...

# %%
# Step 1: List of columns to drop
columns_to_drop = ["DATASET", "SERIES_CODE", "OBS_MEASURE"]

# Step 2: Drop them from the DataFrame
df = df.drop(columns=columns_to_drop)

# %%
df.head()
# Out:
#               COUNTRY                                          INDICATOR  \
# 0             Myanmar    Expenditure, General government, Percent of GDP
# 1           Sri Lanka     Gross debt, General government, Percent of GDP
# 2  Russian Federation  All Items, Consumer price index (CPI), Period ...
# 3  Russian Federation     Gross debt, General government, Percent of GDP
# 4           Sri Lanka    Expenditure, General government, Percent of GDP
#
#   FREQUENCY  SCALE    2005    2006    2007    2008    2009    2010  ...  \
# 0    Annual  Units  14.644  15.602  15.720  14.397  14.446  15.778  ...
# 1    Annual  Units  76.589  74.290  71.849  68.782  72.750  68.731  ...
# 2    Annual  Units  12.685   9.669   9.007  14.111  11.647   6.849  ...
# 3    Annual  Units  14.851   9.804   8.033   7.446   9.918  10.105  ...
# 4    Annual  Units  20.145  20.523  19.876  19.087  21.012  19.310  ...
#
#      2015    2016    2017    2018    2019    2020     2021     2022     2023  \
# ...

# %%
# Step 2: Automatically detect year columns (e.g., 2005–2024)
year_columns = [col for col in df.columns if col.isdigit() and len(col) == 4]

# Step 3: Get ID columns (non-year columns)
id_columns = [col for col in df.columns if col not in year_columns]

# Step 4: Melt to long format
df_long = df.melt(
    id_vars=id_columns,
    value_vars=year_columns,
    var_name="year",
    value_name="value"
)

# Step 5: Convert year to integer
df_long["year"] = df_long["year"].astype(int)

# %%
df_long.head(50)
# Out:
#                         COUNTRY  \
# 0                       Myanmar
# 1                     Sri Lanka
# 2            Russian Federation
# 3            Russian Federation
# 4                     Sri Lanka
# 5                    Bangladesh
# 6                    Bangladesh
# 7                    Bangladesh
# 8                    Bangladesh
# 9                     Sri Lanka
# 10                       Brazil
# 11                       Brazil
# 12                       Brazil
# 13                       Brazil
# 14  China, People's Republic of
# 15  China, People's Republic of
# 16                      Myanmar
# 17  China, People's Republic of
# 18  China, People's Republic of
# 19  China, People's Republic of
# 20  China, People's Republic of
# 21                United States
# 22                      Germany
# 23                      Germany
# 24                      Germany
# 25                        India
# 26                        India
# 27                        Italy
# ...

# %%
df_long.to_csv("/home/abhishek/Desktop/IMF/data/processed/WEO/weo_data.csv", index=False)
